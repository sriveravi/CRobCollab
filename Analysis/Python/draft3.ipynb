# %%
import pandas as pd
import numpy as np
import glob
import time

# %pylab inline
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
import matplotlib.pylab as pylab

from matplotlib.backends.backend_pdf import PdfPages
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#define function to load up datafiles
def loadData( fileName, skipR = 0 ):

    files = glob.glob( fileName )  
    df = pd.DataFrame();
    for f in files:
        #subID = f.split('/')[1][0:-4]
        thisSub = pd.read_csv( f,sep='\t', skiprows=skipR)
        #thisSub['subID'] = subID
        df = pd.concat( [df, thisSub ], ignore_index=True)        
    return df

# return true if relevant ( return nan if nan)
def isRel( AOI ):
    if np.isnan( AOI ):
        return np.nan    
    if AOI in [3,4]:
        return True
    else:
        return False

# %%
#load up mix files
# outfile = 'mixDataByTrial.txt'
# files = 'DataMix/*.txt'
# rawColumns = [ 'subid', 'TRAIL_INDEX', 'trialTime','RESPONSE', 'RT', 'stimulus','target_auditory','target_visual', 'test_auditory','test_visual'] #, 'trial'

# # load up mix files (word condition)
# outfile = 'mixWordDataByTrial.txt'
# files = 'DataWordMix/*.txt'
# rawColumns = [ 'subid', 'TRAIL_INDEX', 'trialTime','RESPONSE', 'RT', 'stimulus','target_auditory','target_visual', 'test_auditory','test_visual'] #'trial'


#-------------
# #the visual condition
# outfile = 'visDataByTrial.txt'
# files = 'DataVis/*.txt'
# rawColumns = [ 'subid',  'TRAIL_INDEX', 'trialTime','RESPONSE', 'RT', 'stimulus','target', 'test'] #,'trial'

# # visual word condition
# outfile = 'visWordDataByTrial.txt'
# files = 'DataWordVis/*.txt'
# rawColumns = [ 'subid', 'TRAIL_INDEX', 'trialTime','RESPONSE', 'RT', 'stimulus','target', 'test']  #, 'trial'

#-------------------------
# aud only files 
outfile = 'audDataByTrial.txt'
files = 'DataAud/*.txt'
rawColumns = [ 'subid', 'TRAIL_INDEX','RESPONSE', 'RT', 'stimulus','target_auditory', 'test_auditory'] # , 'trial'

# # word only files (word condition)
# outfile = 'wordDataByTrial.txt'
# files = 'DataWord/*.txt'
# rawColumns = [ 'subid', 'TRAIL_INDEX', 'trialTime','RESPONSE', 'RT', 'stimulus','target_auditory','target_visual', 'test_auditory','test_visual'] # , 'trial'


df = loadData( files )
df[ 'relFix' ] = df[ 'fixAois'].apply( lambda(x): isRel(x))
df[ 'relSac' ] = df[ 'sacAois'].apply( lambda(x): isRel(x))
# df[[ 'fixAois', 'relFix', 'sacAois', 'relSac'] ]

# %%
df.columns
# Out:
# Index([u'trial', u'TRAIL_INDEX', u'RESPONSE', u'RT', u'KEYPRESS', u'DISPLAY_ON_TIME', u'KEY_RESPONSE_TIME', u'type', u'stimulus', u'target_auditory', u'test_auditory', u'correct_response_auditory', u'target_visual', u'test_visual', u'correct_response', u'trialTime', u'subid', u'fixX', u'fixY', u'pupil', u'fixDuration', u'fixStart', u'fixEnd', u'sacEndPosX', u'sacEndPosY', u'sacStartPosX', u'sacStartPosY', u'sacStartTime', u'sacEndTime', u'sacVel', u'sacDuration', u'sacAmp', u'fixAois', u'sacAois', u'lastMessage', u'relFix', u'relSac'], dtype='object')

# %%
# define a bunch of functions that extract the basic variables

def latFix( someTrials, startTime):
    # latency to first fixation
    if len(someTrials) > 0:
        lat = someTrials.fixStart.min() - startTime
        return lat
    else:
        return np.nan

def meanFixDur(someTrials ):
    # calc mean fixation duration
    return someTrials.fixDuration.mean()

def meanPupSize(someTrials ):
    # calc mean fixation duration
    return someTrials.pupil.mean()

def numFixSac( someTrials):
    # calculate number fixations and number saccades
    numFix =  someTrials['fixStart'].count()
    numSac =  someTrials['sacAmp'].count()
    return (numFix, numSac)

#
def sacAmp( someTrials):
    return someTrials.sacAmp.sum()

# return nan if no looks, or proportion look at relevant
def propRel( someTrials ):    
    relLook = someTrials[ someTrials.relFix == True].fixDuration.sum()    
    allLook = someTrials['fixDuration'].sum()
    if allLook == 0:
        return np.nan
    else:
        return relLook/float(allLook)
  
def firstRel( someTrials ):
    fix = someTrials[ someTrials.fixDuration >= 0 ]
    if len(fix >0 ):
        return fix.relFix.iloc[0]

# lat = latFix( target, targOn[0])
# latRel = latFix( target[ target.relFix == True ], targOn[0])

# mDur = meanFixDur( target)
# pup = meanPupSize( target)
# (nFix, nSac) = numFixSac( target)
# sAmp = sacAmp( target)

# relProp = propRel( target )

# print lat,latRel, mDur, pup, (nFix, nSac), sAmp, relProp

# %%
# Loop through trials and calculate measures

dfByTrial = pd.DataFrame();
subs = df.subid.unique()
for s in subs:
    trials = sort(df[ (df.subid == s)].TRAIL_INDEX.unique())
    for t in trials:
        #summarize this trial dv's
        thisTrialRaw = df[ (df.subid == s) & (df.TRAIL_INDEX == t)]   # raw dv's              
        thisTrial = thisTrialRaw[ rawColumns ] 
        thisTrial = thisTrial[:1] # just first row
        
        #-------------
        # get target and test fixations/saccades\
        if 'trialTime' in thisTrial.columns:
            targOn = thisTrial.trialTime.as_matrix()
            # from display on -> 1000 ms
            target = thisTrialRaw[ (thisTrialRaw.fixStart < targOn[0]+1000) 
                                  | (thisTrialRaw.sacStartTime < targOn[0]+1000 ) ]        
            # from 2000ms after display on
            test = thisTrialRaw[ (thisTrialRaw.fixStart > targOn[0]+2000)  
                                | (thisTrialRaw.sacStartTime > targOn[0]+2000  ) ]
            #-------------            
            # now calculate other measures (on target  )
            thisTrial['trgLatFix'] = latFix( target, targOn[0])                
            thisTrial['trgLatRelFix'] = latFix( target[ target.relFix == True ], targOn[0])
            thisTrial['trgMDur'] = meanFixDur( target)
            thisTrial['trgMpup'] = meanPupSize( target)
            (thisTrial['trgNFix'], thisTrial['trgNSac']) = numFixSac( target)
            thisTrial['trgSAmp'] = sacAmp( target)
            thisTrial['trgRelProp'] = propRel( target )
            thisTrial['trgFirstFixRel'] =  firstRel( target )

            # now calculate other measures (on test )
            thisTrial['tstLatFix'] = latFix( test, targOn[0]+2000)                
            thisTrial['tstLatRelFix'] = latFix( test[ test.relFix == True ], targOn[0]+2000)
            thisTrial['tstMDur'] = meanFixDur( test)
            thisTrial['tstMpup'] = meanPupSize( test)
            (thisTrial['tstNFix'], thisTrial['tstNSac']) = numFixSac( test)
            thisTrial['tstSAmp'] = sacAmp( test)
            thisTrial['tstRelProp'] = propRel( test )        
            thisTrial['tstFirstFixRel'] =  firstRel( test )

        # concatenate to big list
        dfByTrial = pd.concat( [dfByTrial, thisTrial ], ignore_index=True)

# %%
# dfByTrial
# trgDF
# thisTrial

# trials

# %%
# dfByTrial
# target

# %%
# test

# %%
dfByTrial['logRT'] = np.log(dfByTrial.RT-2000)  #subtract 2 seconds
dfByTrial.to_csv(outfile ,sep='\t', mode='w')

# %%
# test['relFix']

# %%
dfByTrial
# Out:
#      subid  TRAIL_INDEX  trialTime   RESPONSE     RT stimulus target_auditory  \
# 0       10            1     555878    Correct  11822     A2V6         A2B.wav
# 1       10            2     570596    Correct   3219     A9V9          A9.wav
# 2       10            3     575656  Incorrect   3256     A9V9         A9B.wav
# 3       10            4     581547    Correct   2966     A4V7          A4.wav
# 4       10            5     586053    Correct   2912     A4V7         A4B.wav
# 5       10            6     591447    Correct   2969     A9V9         A9B.wav
# 6       10            7     595762    Correct   3173     A2V6          A2.wav
# 7       10            8     600197    Correct   3020     A5V8         A5B.wav
# 8       10            9     664752    Correct   2817     A2V6          A2.wav
# 9       10           10     669039    Correct   2647     A5V8          A5.wav
# 10      10           11     672869    Correct   2733     A4V7          A4.wav
# 11      10           12     677203    Correct   2728     A9V9          A9.wav
# 12      10           13     681255    Correct   2654     A5V8         A5B.wav
# 13      10           14     685123    Correct   2796     A4V7         A4B.wav
# 14      10           15     689362    Correct   2882     A5V8          A5.wav
# 15      10           16     693519    Correct   2772     A2V6         A2B.wav
# 16      10           17     749949    Correct   2615     A2V6         A2B.wav
# 17      10           18     753917    Correct   2824     A4V7         A4B.wav
# 18      10           19     758321    Correct   2743     A9V9         A9B.wav
# 19      10           20     762477    Correct   2634     A4V7         A4B.wav
# 20      10           21     766287    Correct   2761     A9V9          A9.wav
# 21      10           22     770306    Correct   2698     A2V6         A2B.wav
# 22      10           23     774381    Correct   2640     A5V8         A5B.wav
# 23      10           24     778402    Correct   2542     A9V9         A9B.wav
# 24      10           25     809649    Correct   2613     A9V9          A9.wav
# 25      10           26     813488    Correct   2797     A5V8         A5B.wav
# 26      10           27     817599    Correct   2888     A5V8          A5.wav
# 27      10           28     821948    Correct   2570     A2V6          A2.wav
# 28      10           29     825774  Incorrect   2385     A2V6          A2.wav
# 29      10           30     829167    Correct   2434     A5V8          A5.wav
# ...    ...          ...        ...        ...    ...      ...             ...
# 1130     9           11    1652903  Incorrect   2830     A2V6          A2.wav
# 1131     9           12    1657290    Correct   2856     A9V9         A9B.wav
# 1132     9           13    1661323    Correct   2703     A9V9          A9.wav
# 1133     9           14    1665147    Correct   3167     A2V6          A2.wav
# 1134     9           15    1669451    Correct   2643     A5V8         A5B.wav
# 1135     9           16    1673161    Correct   2565     A2V6         A2B.wav
# 1136     9           17    1707225    Correct   2748     A2V6          A2.wav
# 1137     9           18    1711860    Correct   2661     A5V8          A5.wav
# 1138     9           19    1716185    Correct   2535     A4V7         A4B.wav
# 1139     9           20    1720938    Correct   3218     A2V6          A2.wav
# 1140     9           21    1725933  Incorrect   2553     A5V8         A5B.wav
# 1141     9           22    1730137    Correct   2818     A2V6         A2B.wav
# 1142     9           23    1734120    Correct   2907     A9V9         A9B.wav
# 1143     9           24    1738069    Correct   3020     A4V7          A4.wav
# 1144     9           25    1770745    Correct   2747     A9V9         A9B.wav
# 1145     9           26    1775132    Correct   3141     A5V8         A5B.wav
# 1146     9           27    1779881  Incorrect   2687     A9V9          A9.wav
# 1147     9           28    1783939  Incorrect   2942     A2V6         A2B.wav
# 1148     9           29    1788027    Correct   2929     A5V8          A5.wav
# 1149     9           30    1792277    Correct   2703     A9V9          A9.wav
# 1150     9           31    1796679    Correct   2737     A4V7         A4B.wav
# 1151     9           32    1801042  Incorrect   3202     A4V7          A4.wav
# 1152     9           33    1834162    Correct   2743     A2V6         A2B.wav
# 1153     9           34    1838530    Correct   2521     A2V6         A2B.wav
# 1154     9           35    1843010    Correct   2636     A4V7          A4.wav
# 1155     9           36    1847043    Correct   2613     A5V8         A5B.wav
# 1156     9           37    1850804    Correct   2566     A5V8          A5.wav
# 1157     9           38    1854805  Incorrect   2990     A9V9         A9B.wav
# 1158     9           39    1859471    Correct   2564     A4V7          A4.wav
# 1159     9           40    1863474  Incorrect   3021     A2V6          A2.wav
#
#      target_visual test_auditory test_visual     ...      tstLatFix  \
# 0          V6B.bmp        A2.wav      V6.bmp     ...             77
# 1           V9.bmp       A9B.wav      V9.bmp     ...            871
# 2          V9B.bmp       A9B.wav      V9.bmp     ...            583
# 3           V7.bmp       A4B.wav      V7.bmp     ...            NaN
# 4          V7B.bmp       A4B.wav      V7.bmp     ...            634
# 5          V9B.bmp       A9B.wav     V9B.bmp     ...            626
# 6           V6.bmp        A2.wav     V6B.bmp     ...            867
# 7          V8B.bmp        A5.wav     V8B.bmp     ...            318
# 8           V6.bmp        A2.wav      V6.bmp     ...            775
# 9           V8.bmp        A5.wav     V8B.bmp     ...            NaN
# 10          V7.bmp       A4B.wav     V7B.bmp     ...            NaN
# 11          V9.bmp       A9B.wav     V9B.bmp     ...            710
# 12         V8B.bmp        A5.wav      V8.bmp     ...            586
# 13         V7B.bmp       A4B.wav     V7B.bmp     ...            330
# 14          V8.bmp        A5.wav      V8.bmp     ...            371
# 15         V6B.bmp        A2.wav     V6B.bmp     ...            NaN
# 16         V6B.bmp       A2B.wav     V6B.bmp     ...              1
# 17         V7B.bmp        A4.wav     V7B.bmp     ...            643
# 18         V9B.bmp        A9.wav     V9B.bmp     ...            261
# 19         V7B.bmp        A4.wav      V7.bmp     ...            NaN
# 20          V9.bmp        A9.wav     V9B.bmp     ...            NaN
# 21         V6B.bmp       A2B.wav      V6.bmp     ...            NaN
# 22         V8B.bmp       A5B.wav     V8B.bmp     ...            283
# 23         V9B.bmp        A9.wav      V9.bmp     ...             14
# 24          V9.bmp        A9.wav      V9.bmp     ...            NaN
# 25         V8B.bmp       A5B.wav      V8.bmp     ...            374
# 26          V8.bmp       A5B.wav      V8.bmp     ...            647
# 27          V6.bmp       A2B.wav     V6B.bmp     ...             28
# 28          V6.bmp       A2B.wav      V6.bmp     ...            NaN
# 29          V8.bmp       A5B.wav     V8B.bmp     ...            NaN
# ...            ...           ...         ...     ...            ...
# 1130        V6.bmp        A2.wav     V6B.bmp     ...            NaN
# 1131       V9B.bmp       A9B.wav     V9B.bmp     ...            357
# 1132        V9.bmp       A9B.wav      V9.bmp     ...            NaN
# 1133        V6.bmp        A2.wav      V6.bmp     ...            NaN
# 1134       V8B.bmp        A5.wav     V8B.bmp     ...            NaN
# 1135       V6B.bmp        A2.wav      V6.bmp     ...            NaN
# 1136        V6.bmp       A2B.wav     V6B.bmp     ...            NaN
# 1137        V8.bmp       A5B.wav     V8B.bmp     ...            NaN
# 1138       V7B.bmp        A4.wav     V7B.bmp     ...            NaN
# 1139        V6.bmp       A2B.wav      V6.bmp     ...            830
# 1140       V8B.bmp       A5B.wav      V8.bmp     ...             31
# 1141       V6B.bmp       A2B.wav     V6B.bmp     ...            NaN
# 1142       V9B.bmp        A9.wav      V9.bmp     ...            NaN
# 1143        V7.bmp        A4.wav      V7.bmp     ...            533
# 1144       V9B.bmp        A9.wav     V9B.bmp     ...            431
# 1145       V8B.bmp       A5B.wav     V8B.bmp     ...            760
# 1146        V9.bmp        A9.wav     V9B.bmp     ...            371
# 1147       V6B.bmp       A2B.wav      V6.bmp     ...            493
# 1148        V8.bmp       A5B.wav      V8.bmp     ...            829
# 1149        V9.bmp        A9.wav      V9.bmp     ...            535
# 1150       V7B.bmp        A4.wav      V7.bmp     ...            739
# 1151        V7.bmp        A4.wav     V7B.bmp     ...            386
# 1152       V6B.bmp        A2.wav     V6B.bmp     ...            NaN
# 1153       V6B.bmp        A2.wav      V6.bmp     ...            NaN
# 1154        V7.bmp       A4B.wav      V7.bmp     ...            NaN
# 1155       V8B.bmp        A5.wav      V8.bmp     ...            NaN
# 1156        V8.bmp        A5.wav      V8.bmp     ...            NaN
# 1157       V9B.bmp       A9B.wav      V9.bmp     ...            745
# 1158        V7.bmp       A4B.wav     V7B.bmp     ...            NaN
# 1159        V6.bmp        A2.wav     V6B.bmp     ...            114
#
#       tstLatRelFix     tstMDur     tstMpup  tstNFix  tstNSac  tstSAmp  \
# 0               77  344.000000  409.111111        9        9    59.25
# 1              NaN  378.000000  358.000000        1        1     2.73
# 2              NaN  343.000000  348.000000        2        2     4.37
# 3              NaN         NaN         NaN        0        0     0.00
# 4              NaN  316.000000  321.000000        1        1     6.75
# 5              626  370.000000  337.000000        1        1     1.53
# 6              867  334.000000  298.000000        1        1     2.93
# 7              318  728.000000  289.000000        1        1     4.38
# 8              NaN   74.000000  267.000000        1        1     2.21
# 9              NaN         NaN         NaN        0        1     3.80
# 10             NaN         NaN         NaN        0        0     0.00
# 11             NaN   46.000000  298.000000        1        1     5.37
# 12             NaN   94.000000  243.000000        1        1     4.77
# 13             330  490.000000  290.000000        1        1     4.36
# 14             NaN  246.000000  154.000000        2        2    23.96
# 15             NaN         NaN         NaN        0        0     0.00
# 16             NaN  640.000000  279.000000        1        0      NaN
# 17             643  206.000000  302.000000        1        1     5.79
# 18             261  518.000000  232.000000        1        1     4.44
# 19             NaN         NaN         NaN        0        0     0.00
# 20             NaN         NaN         NaN        0        0     0.00
# 21             NaN         NaN         NaN        0        0     0.00
# 22             283  382.000000  198.000000        1        1     3.04
# 23             NaN  564.000000  217.000000        1        0      NaN
# 24             NaN         NaN         NaN        0        0     0.00
# 25             NaN  209.000000  232.000000        2        2    10.54
# 26             NaN  278.000000  260.000000        1        1     4.71
# 27             NaN  578.000000  243.000000        1        1     0.90
# 28             NaN         NaN         NaN        0        0     0.00
# 29             NaN         NaN         NaN        0        0     0.00
# ...            ...         ...         ...      ...      ...      ...
# 1130           NaN         NaN         NaN        0        0     0.00
# 1131           799  155.333333  216.000000        3        3    10.07
# 1132           NaN         NaN         NaN        0        0     0.00
# 1133           NaN         NaN         NaN        0        0     0.00
# 1134           NaN         NaN         NaN        0        0     0.00
# 1135           NaN         NaN         NaN        0        0     0.00
# 1136           NaN         NaN         NaN        0        0     0.00
# 1137           NaN         NaN         NaN        0        0     0.00
# 1138           NaN         NaN         NaN        0        0     0.00
# 1139           NaN  198.000000  251.000000        2        2     4.07
# 1140           NaN  558.000000  193.000000        1        1     1.04
# 1141           NaN         NaN         NaN        0        0     0.00
# 1142           NaN         NaN         NaN        0        0     0.00
# 1143           NaN  146.000000  223.666667        3        3    20.12
# 1144           NaN  352.000000  230.000000        1        1     0.92
# 1145           NaN  190.000000  246.000000        2        2     8.68
# 1146           NaN  350.000000  218.000000        1        1     1.35
# 1147           493  219.000000  200.500000        2        2     4.62
# 1148           NaN  136.000000  228.000000        1        1     1.61
# 1149           535  204.000000  203.000000        1        1     1.97
# 1150           739   32.000000  208.000000        1        1     3.11
# 1151           386  192.500000  211.000000        4        4    11.65
# 1152           NaN         NaN         NaN        0        0     0.00
# 1153           NaN         NaN         NaN        0        0     0.00
# 1154           NaN         NaN         NaN        0        0     0.00
# 1155           NaN         NaN         NaN        0        0     0.00
# 1156           NaN         NaN         NaN        0        0     0.00
# 1157           NaN  146.000000  201.000000        1        2    38.96
# 1158           NaN         NaN         NaN        0        0     0.00
# 1159           NaN  215.000000  211.000000        4        4    10.70
#
#       tstRelProp tstFirstFixRel     logRT
# 0       0.063953           True  9.192380
# 1       0.000000          False  7.105786
# 2       0.000000          False  7.135687
# 3            NaN           None  6.873164
# 4       0.000000          False  6.815640
# 5       1.000000           True  6.876265
# 6       1.000000           True  7.067320
# 7       1.000000           True  6.927558
# 8       0.000000          False  6.705639
# 9            NaN           None  6.472346
# 10           NaN           None  6.597146
# 11      0.000000          False  6.590301
# 12      0.000000          False  6.483107
# 13      1.000000           True  6.679599
# 14      0.000000          False  6.782192
# 15           NaN           None  6.648985
# 16      0.000000          False  6.421622
# 17      1.000000           True  6.714171
# 18      1.000000           True  6.610696
# 19           NaN           None  6.452049
# 20           NaN           None  6.634633
# 21           NaN           None  6.548219
# 22      1.000000           True  6.461468
# 23      0.000000          False  6.295266
# 24           NaN           None  6.418365
# 25      0.000000          False  6.680855
# 26      0.000000          False  6.788972
# 27      0.000000          False  6.345636
# 28           NaN           None  5.953243
# 29           NaN           None  6.073045
# ...          ...            ...       ...
# 1130         NaN           None  6.721426
# 1131    0.201717          False  6.752270
# 1132         NaN           None  6.555357
# 1133         NaN           None  7.062192
# 1134         NaN           None  6.466145
# 1135         NaN           None  6.336826
# 1136         NaN           None  6.617403
# 1137         NaN           None  6.493754
# 1138         NaN           None  6.282267
# 1139    0.000000          False  7.104965
# 1140    0.000000          False  6.315358
# 1141         NaN           None  6.706862
# 1142         NaN           None  6.810142
# 1143    0.000000          False  6.927558
# 1144    0.000000          False  6.616065
# 1145    0.000000          False  7.039660
# 1146    0.000000          False  6.532334
# 1147    1.000000           True  6.848005
# 1148    0.000000          False  6.834109
# 1149    1.000000           True  6.555357
# 1150    1.000000           True  6.602588
# 1151    0.711688           True  7.091742
# 1152         NaN           None  6.610696
# 1153         NaN           None  6.255750
# 1154         NaN           None  6.455199
# 1155         NaN           None  6.418365
# 1156         NaN           None  6.338594
# 1157    0.000000          False  6.897705
# 1158         NaN           None  6.335054
# 1159    0.000000          False  6.928538
#
# [1160 rows x 29 columns]
